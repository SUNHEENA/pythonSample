# %% [markdown]
# 📜Intermediate Test<BR>
# 모든 문제를 풀이가 가능한 라이브러리를 명시 해 드렸습니다.<BR>
# 하지만 다른 라이브러리로 문제를 해결하셔도 점수에 영향을 받지 않습니다
# # library(5점)
# 아래 code의 문제점을 파악 하고 수정 하여 code를 복원 해 봅시다.<BR>
#     <font color='red'>''</font> 안의 경로는 여러분이 가지신 엑셀 파일 employee_list.csv를 넣고 구현 부탁 드립니다.

# %%
import pandas as pd
#code를 바로 변경하여 답안을 완성 해 주세요.
excelDF = pd.read_excel('data/employee_list.csv')

# %% [markdown]
# 예상되는 결과
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1번에서 가져온 DataFrame 을 가지고 새로운 열을 추가 해 주세요(5점)
# ['판별'] 판별이라는 열을 생성 해 주고 apply 함수를 통해
# 36세 미만은 Y 아닌 경우는 N을 넣어 주세요
# <br>📚libary :<font color='red'> pandas</font>

# %%
예상되는 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
###################1.1 번문제 code 작성 공간#########################################

# %% [markdown]
# # Pandas 다루기(10점)
# IM_TEST_DF1.xlsx 파일을 불러와 salary가 200,000 원 <BR>
# 이상인 사람들만 집계 해 주세요.<br>
#     그리고 TITLE에는 <font color='red'>사원</font>이라는 문구가 포함 된 인원만 집계 해 주세요.
# <br>📚libary :<font color='red'> pandas</font>

# %% [markdown]
# 원본 엑셀
# ![image.png](attachment:image.png)

# %% [markdown]
# 예상되는 결과
# ![image.png](attachment:image.png)

# %%
###################2 번문제 code 작성 공간#########################################

# %% [markdown]
# # Pandas 다루기2(20점)
# 1. IM_TEST_DF1.xlsx , IM_TEST_DF2.xlsx 파일 load.
# 2. 불러온 <font color='red'>DataFrame</font>을 하나로 합치기.
# 3. 합쳐진 결과에서 행 데이터 중 하나라도 <br>Nan으로 표기된 데이터는 삭제.
# 4. 연봉이 240,000 이하인 사람만 집계.
# 5. 이름이 중복인 사람은 첫 번째 사람만 남겨 주고 중복은 제거.
# 6. NAME과 TITLE로만 구성 된 DataFrame을 재 생성하여 출력.
# <br>📚libary :<font color='red'> pandas</font>

# %%
load 후 합쳐진 DF

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
예상되는 최종 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
###################3 번문제 code 작성 공간#########################################

# %% [markdown]
# # selenium or BeautifulSoup 활용(10점)
# 네이버에 접속하여 INPUT 받는 기업의 주가를 출력 해 주세요<Br>
# tip : class로 text를 가져오면 원치 않은 정보도
# <BR> 포함이 될 수 있습니다.<BR>
# 이를 제거 하기 위해선 어떤 작업이 필요 할까요?
# <br>📚libary :<font color='red'> BeautifulSoup,requests,webdriver,ChromeDriverManager</font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 예상되는 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
###################4 번문제 code 작성 공간#########################################

# %% [markdown]
# # 멜론차트 구하기(15점)
# 멜론의 실시간 차트를 1~100위를 구해 가수와 제목을 가져와 주세요.
# <br>📚libary :<font color='red'> BeautifulSoup,requests,webdriver,ChromeDriverManager</font>
# ![image.png](attachment:image.png)

# %%
예상되는 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
###################5 번문제 code 작성 공간#########################################

# %% [markdown]
# # 5번 에서 가져온 결과로 DataFrame을 생성(15점)
# 항목은 그대로 가수, 제목 으로 생성
# <br>📚libary :<font color='red'> BeautifulSoup,requests,webdriver,ChromeDriverManager,pandas</font>

# %%
예상되는 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
###################6 번문제 code 작성 공간#########################################

# %% [markdown]
# # DataFrame 그래프 만들기(5점)
# 1. employee_list_g.csv 파일을 불러 옵니다.
# ![image-2.png](attachment:image-2.png)
#
# 2. x 축 부서 y축 나이로 bar 그래프를 만들어 주세요.
# 3. 그래프 밖 배경은 회색(#3b3b3b) 으로 변경 해 주세요.
# 4. font는 Malgun Gothic 지정 x,y축 font 는 흰색으로 변경 해 주세요.
# 5. title은 -  파트별 나이현황 으로 해 주세요. 색상은 흰색
# <br>📚libary :<font color='red'> matplotlib,pandas</font>

# %%
예상되는 결과

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
###################7 번문제 code 작성 공간#########################################

# %% [markdown]
# # DataFrame 그래프 만들기 2(15점)
# 1. 7번 엑셀 파일을 그대로 불러와 줍니다.
# 2. 불러온 엑셀 파일에서 연령대별 인원을 count 하여 DataFrame을 구해 줍니다.
# 3. 엑셀의 연령대는 20대 - 70대까지 존재 합니다.<BR>
# 이를 가변적으로 가져오기 위해선 어떤 작업이 필요 할까요? 만약 구현이 어려운 경우 10~70대를 hardcoding으로 만드셔도 됩니다.
# <br><font color='red'>하지만 하드코딩의 경우 점수는 차감</font>
# ![image-4.png](attachment:image-4.png)
# <font color='red'>hardcoding 예시 </font><br>
# <font color='green'>ageDictionary = {'10대':0,'20대',:0,'30대',0....}</font>
# 4. 해당 count로 연령대 별 scatter 그래프를 구현 해 주세요.
# 5. 폰트 및 색상 은 7번 그래프와 동일한 옵션 사용 표시 . 닷의 color는 해당 색상 사용(빨강: #d9534f)
# 6. 그래프 배경 라인 처리 점선으로 처리linestyle='--' (가산점)
# <br>📚libary :<font color='red'> matplotlib,pandas</font>
# <br>📚함수 :<font color='red'> set, pd.DataFrame..</font>

# %%
예상되는 그래프 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
##################8 번문제 code 작성 공간#########################################
