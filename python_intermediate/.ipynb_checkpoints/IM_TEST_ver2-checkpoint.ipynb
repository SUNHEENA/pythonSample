# %%
📄 Description 💯: DF = DataFrame
    1. html 의 데이터를 DF로 변환 합니다. [webdriver 사용]
    2. 엑셀의 데이터를 DF로 변환 합니다.
    3. 1,2의 결과로 얻어낸 결과를 OUTLOOK 이메일로 전송 시킵니다.
필요한 라이브러리    
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import win32com.client

📄 Detailed Description:
📜1. name_list 라는 html 파일에서 데이터 html의 데이터를 
   parshing 하여 원본 명단 1번 df를 만들어 줍니다.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
Pharshing 후 df는 아래와 같은 형태가 될 것으로 예상 됩니다.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
📜2. 해당 DF에서 직책이 책임인 df을 구합니다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
📜3. [1,2] 과정에서 얻어낸 DF에서 소속이 일치하는 
입사정보파일.xls 의 데이터 LIST만을 추출 합니다.
🔺 1,2의 결과로 얻어낸 소속은 IT팀,기술연구소이 총2개 입니다.
입사정보파일.xls에서 얻어오는 데이터는 IT팀의 소속의 데이터
기술연구소 데이터가 이렇게 각각 발생 하겠네요.

좌 - 크롤링 DF, 우- 엑셀 에서 가져온 DF

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
📜4. -> 이름, 근무지, 입사일 만을 DF로 새롭게 구성하여 생성합니다.
    -> 해당 데이터 프레임에서 입사일은 년도만(YYYY) 잘라냅니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
이메일 전송 시 최종 완성 DF 예상결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
📜5. 여기까지 얻어진 결과를 DF를 아래와 같은 형태로 이메일로 보내 주세요.
[1,2]과정에서 얻어진 DF를 for문 돌면서 email 은 전송을 시켜 주시면 됩니다.
이메일 주소는 해당 DF에서 얻어진 결과의 이메일 주소로 보내 주시면 됩니다.
❗저에게 이메일이 와야 합니다❗
이메일 전송은 춘식이 일때만 전송 부탁 드리고
제목에는 이름+소속을 붙여 전송 부탁 드립니다.
더불어 전송 시 표의 가장 최상단 색상은 rgb 204,217,255 색상
으로 해 주세요.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
