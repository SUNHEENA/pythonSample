# %%
기초 평가문제. 판다스+크롤링
필요한 라이브러리

import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

1. name_list 라는 html 파일에서 데이터 크롤링을 통해 원본 명단 1번 df를 만들어 줍니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df는 아래와 같은 형태가 될 것으로 예상 됩니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2. 해당 DF에서 직책이 책임인 df을 구합니다
3. [1,2] 과정에서 얻어낸 DF에서 소속이 일치하는 입사정보파일.xls 의 데이터 LIST만을 구합니다.
좌 - 크롤링 DF, 우- 엑셀 에서 가져온 DF

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
4. -> 이름, 근무지, 입사일 만을 DF로 새롭게 구성하여 생성합니다.
    -> 해당 데이터 프레임에서 입사일은 년도만(YYYY) 잘라냅니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5. 해당 결과를 하나의 엑셀파일로 생성하셔서 작성하신 파이썬 code와 함께
   이메일로 저희에게 보내 주세요!
   엑셀로 저장 시 파일명은 소속명_기초TEST_Result로 부탁 드립니다.

# %%
예상되는 결과 - 엑셀파일.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
